# %%
import torch
import torch.nn as nn
from dataloaders import load_cifar10
from trainer import Trainer, compute_loss_and_accuracy
from task2 import create_plots, output_features
import numpy as np

# %%
class ExampleModel(nn.Module):

    def __init__(self,
                 image_channels,
                 num_classes):
        """
            Is called when model is initialized.
            Args:
                image_channels. Number of color channels in image (3)
                num_classes: Number of classes we want to predict (10)
        """
        super().__init__()
        # TODO: Implement this function (Task  2a)
        #Number of filters in conv layers
        num_filters1 = 32; num_filters2 = 64; num_filters3 = 128; num_filters4 = 128
        kernel_conv = 3; stride_conv = 1; padding_conv = 2
        kernel_pool = 2; stride_pool = 2
        
        
        self.num_classes = num_classes
        # Define the convolutional layers
        self.feature_extractor = nn.Sequential(
            nn.Conv2d(in_channels=image_channels, out_channels=num_filters1, kernel_size= kernel_conv,stride=stride_conv,padding=padding_conv),
            nn.BatchNorm2d(num_filters1),
            nn.ReLU(), 
            nn.MaxPool2d(kernel_size=kernel_pool, stride = stride_pool),
            
            nn.Conv2d(in_channels=num_filters1,  out_channels=num_filters2, kernel_size=kernel_conv,stride=stride_conv,padding=padding_conv),
            nn.BatchNorm2d(num_filters2),
            nn.ReLU(), 
            nn.MaxPool2d(kernel_size=kernel_pool, stride = stride_pool),
           
            nn.Conv2d(in_channels=num_filters2,   out_channels=num_filters3, kernel_size=kernel_conv,stride=stride_conv,padding=padding_conv),
            nn.BatchNorm2d(num_filters3),
            nn.ReLU(), 
            nn.MaxPool2d(kernel_size=kernel_pool, stride = stride_pool),
            
            nn.Conv2d(in_channels=num_filters3,   out_channels=num_filters4, kernel_size=kernel_conv,stride=stride_conv,padding=padding_conv),
            nn.BatchNorm2d(num_filters4),
            nn.ReLU(), 
            nn.MaxPool2d(kernel_size=kernel_pool, stride = stride_pool)
            
            )

        
        # The output of feature_extractor will be [batch_size, num_filters, 16, 16]
        #self.num_output_features = 32*32*32

        filters_list = [num_filters1, num_filters2, num_filters3, num_filters4]
        out2 = num_filters1
        for filter in filters_list:
             out_channels = filter
             out1 = np.floor((out2 + 2*padding_conv - kernel_conv) / stride_conv) + 1
             out2 = np.floor((out1 - kernel_pool) / stride_pool) + 1
             self.num_output_features = int(out_channels * out2 * out2)

        #self.num_output_features = output_features(num_filters1, num_filters2, num_filters3, num_filters4,kernel_conv, stride_conv, padding_conv, kernel_pool, stride_pool)
        linear_filter1 = 64

        # Initialize our last fully connected layer
        # Inputs all extracted features from the convolutional layers
        # Outputs num_classes predictions, 1 for each class.
        # There is no need for softmax activation function, as this is
        # included with nn.CrossEntropyLoss
        self.classifier = nn.Sequential(
            #nn.Linear(self.num_output_features, num_classes),
            nn.Linear(self.num_output_features, self.num_output_features),
            nn.BatchNorm1d(self.num_output_features),
            nn.ReLU(),
            nn.Linear(self.num_output_features, linear_filter1),
            nn.BatchNorm1d(linear_filter1),
            nn.ReLU(),
            nn.Linear(linear_filter1, num_classes))
      

    def forward(self, x):
        """
        Performs a forward pass through the model
        Args:
            x: Input image, shape: [batch_size, 3, 32, 32]
        """
        batch_size = x.shape[0]
        out = self.feature_extractor(x)
        out = out.view(batch_size, -1)
        out = self.classifier(out)        
        expected_shape = (batch_size, self.num_classes)
        assert out.shape == (batch_size, self.num_classes),\
            f"Expected output of forward pass to be: {expected_shape}, but got: {out.shape}"
        return out

# %%
#With batch norm in classifier
#With augment_triain in augmented train
#With L2 regularisation 
#With Momentum 

epochs = 10
batch_size = 64
learning_rate = 5e-2 # Should be 5e-5 for LeNet
early_stop_count = 4

new_mean_std = False 
resize = 0
transform = 'flip'
dataloaders = load_cifar10(resize, new_mean_std, transform , batch_size)


l2_reg_lambda = 0.005 #1e-5
momentum = 0.08 
optimizer = 'SGD'
model = ExampleModel(image_channels=3, num_classes=10)
trainer = Trainer(batch_size, learning_rate, early_stop_count, epochs, model, dataloaders, l2_reg_lambda, momentum, optimizer)

trainer.train()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# ExampleModel(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (9): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (12): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (13): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): ReLU()
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=1152, out_features=1152, bias=True)
#     (1): BatchNorm1d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=1152, out_features=64, bias=True)
#     (4): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# Epoch: 0, Bps: 43.84, Global step:    781,
#  Train Loss: 1.09, Train Acc: 0.628, Val Loss: 1.06, Val Acc: 0.630, Test Loss: 1.13, Test Acc: 0.615
# Epoch: 0, Bps: 43.99, Global step:   1562,
#  Train Loss: 0.75, Train Acc: 0.744, Val Loss: 0.75, Val Acc: 0.746, Test Loss: 0.82, Test Acc: 0.716
# Epoch: 1, Bps: 44.52, Global step:   2343,
#  Train Loss: 0.67, Train Acc: 0.772, Val Loss: 0.65, Val Acc: 0.779, Test Loss: 0.77, Test Acc: 0.735
# Epoch: 1, Bps: 44.40, Global step:   3124,
#  Train Loss: 0.59, Train Acc: 0.805, Val Loss: 0.58, Val Acc: 0.803, Test Loss: 0.70, Test Acc: 0.758
# Epoch: 2, Bps: 44.71, Global step:   3905,
#  Train Loss: 0.51, Train Acc: 0.830, Val Loss: 0.47, Val Acc: 0.843, Test Loss: 0.67, Test Acc: 0.770
# Epoch: 2, Bps: 44.70, Global step:   4686,
#  Train Loss: 0.60, Train Acc: 0.796, Val Loss: 0.58, Val Acc: 0.801, Test Loss: 0.74, Test Acc: 0.744
# Epoch: 3, Bps: 44.91, Global step:   5467,
#  Train Loss: 0.63, Train Acc: 0.781, Val Loss: 0.59, Val Acc: 0.794, Test Loss: 0.82, Test Acc: 0.720
# Epoch: 3, Bps: 44.95, Global step:   6248,
#  Train Loss: 0.59, Train Acc: 0.794, Val Loss: 0.58, Val Acc: 0.808, Test Loss: 0.76, Test Acc: 0.735
# Early stop criteria met
# Early stopping.

# %%
#With batch norm in classifier
#With augment_triain in augmented train
#With L2 regularisation 
#Without Momentum 

epochs = 10
batch_size = 64
learning_rate = 5e-2 # Should be 5e-5 for LeNet
early_stop_count = 4

new_mean_std = False 
resize = 0
transform = 'flip'
dataloaders = load_cifar10(resize, new_mean_std, transform , batch_size)


l2_reg_lambda = 0.005 #1e-5
momentum = 0 #0.08 
optimizer = 'SGD'
model = ExampleModel(image_channels=3, num_classes=10)
trainer = Trainer(batch_size, learning_rate, early_stop_count, epochs, model, dataloaders, l2_reg_lambda, momentum, optimizer)

trainer.train()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# ExampleModel(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (9): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (12): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (13): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): ReLU()
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=1152, out_features=1152, bias=True)
#     (1): BatchNorm1d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=1152, out_features=64, bias=True)
#     (4): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# Epoch: 0, Bps: 46.42, Global step:    781,
#  Train Loss: 0.97, Train Acc: 0.665, Val Loss: 0.94, Val Acc: 0.677, Test Loss: 1.01, Test Acc: 0.653
# Epoch: 0, Bps: 45.19, Global step:   1562,
#  Train Loss: 0.90, Train Acc: 0.697, Val Loss: 0.88, Val Acc: 0.699, Test Loss: 0.96, Test Acc: 0.675
# Epoch: 1, Bps: 45.16, Global step:   2343,
#  Train Loss: 0.70, Train Acc: 0.762, Val Loss: 0.67, Val Acc: 0.772, Test Loss: 0.80, Test Acc: 0.726
# Epoch: 1, Bps: 44.64, Global step:   3124,
#  Train Loss: 0.62, Train Acc: 0.793, Val Loss: 0.60, Val Acc: 0.801, Test Loss: 0.73, Test Acc: 0.751
# Epoch: 2, Bps: 44.72, Global step:   3905,
#  Train Loss: 0.62, Train Acc: 0.786, Val Loss: 0.58, Val Acc: 0.802, Test Loss: 0.78, Test Acc: 0.736
# Epoch: 2, Bps: 44.62, Global step:   4686,
#  Train Loss: 0.51, Train Acc: 0.830, Val Loss: 0.48, Val Acc: 0.842, Test Loss: 0.66, Test Acc: 0.776
# Epoch: 3, Bps: 44.79, Global step:   5467,
#  Train Loss: 0.50, Train Acc: 0.832, Val Loss: 0.45, Val Acc: 0.853, Test Loss: 0.69, Test Acc: 0.768
# Epoch: 3, Bps: 44.71, Global step:   6248,
#  Train Loss: 0.46, Train Acc: 0.846, Val Loss: 0.44, Val Acc: 0.859, Test Loss: 0.64, Test Acc: 0.783
# Epoch: 4, Bps: 44.85, Global step:   7029,
#  Train Loss: 0.53, Train Acc: 0.817, Val Loss: 0.48, Val Acc: 0.839, Test Loss: 0.77, Test Acc: 0.745
# Epoch: 4, Bps: 44.84, Global step:   7810,
#  Train Loss: 0.47, Train Acc: 0.845, Val Loss: 0.45, Val Acc: 0.857, Test Loss: 0.66, Test Acc: 0.780
# Epoch: 5, Bps: 44.97, Global step:   8591,
#  Train Loss: 0.48, Train Acc: 0.840, Val Loss: 0.43, Val Acc: 0.861, Test Loss: 0.72, Test Acc: 0.757
# Epoch: 5, Bps: 44.93, Global step:   9372,
#  Train Loss: 0.56, Train Acc: 0.807, Val Loss: 0.53, Val Acc: 0.818, Test Loss: 0.78, Test Acc: 0.743
# Epoch: 6, Bps: 45.04, Global step:  10153,
#  Train Loss: 0.68, Train Acc: 0.768, Val Loss: 0.63, Val Acc: 0.785, Test Loss: 0.96, Test Acc: 0.694
# Epoch: 6, Bps: 45.01, Global step:  10934,
#  Train Loss: 0.46, Train Acc: 0.844, Val Loss: 0.43, Val Acc: 0.858, Test Loss: 0.68, Test Acc: 0.771
# Epoch: 7, Bps: 45.07, Global step:  11715,
#  Train Loss: 0.42, Train Acc: 0.861, Val Loss: 0.36, Val Acc: 0.885, Test Loss: 0.71, Test Acc: 0.768
# Epoch: 7, Bps: 44.96, Global step:  12496,
#  Train Loss: 0.45, Train Acc: 0.850, Val Loss: 0.43, Val Acc: 0.862, Test Loss: 0.69, Test Acc: 0.771
# Epoch: 8, Bps: 44.99, Global step:  13277,
#  Train Loss: 0.53, Train Acc: 0.826, Val Loss: 0.46, Val Acc: 0.844, Test Loss: 0.83, Test Acc: 0.733
# Epoch: 8, Bps: 45.00, Global step:  14058,
#  Train Loss: 0.45, Train Acc: 0.849, Val Loss: 0.43, Val Acc: 0.856, Test Loss: 0.69, Test Acc: 0.767
# Early stop criteria met
# Early stopping.

# %%
#With batch norm in classifier
#With augment_triain in augmented train
#With L2 regularisation 
#Without Momentum 
#With only 2 layers classifier

epochs = 10
batch_size = 64
learning_rate = 5e-2 # Should be 5e-5 for LeNet
early_stop_count = 4

new_mean_std = False 
resize = 0
transform = 'flip'
dataloaders = load_cifar10(resize, new_mean_std, transform , batch_size)


l2_reg_lambda = 0.005 #1e-5
momentum = 0 #0.08 
optimizer = 'SGD'
model = ExampleModel(image_channels=3, num_classes=10)
trainer = Trainer(batch_size, learning_rate, early_stop_count, epochs, model, dataloaders, l2_reg_lambda, momentum, optimizer)

trainer.train()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# ExampleModel(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (9): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (12): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (13): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): ReLU()
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=1152, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# Epoch: 0, Bps: 45.28, Global step:    781,
#  Train Loss: 0.98, Train Acc: 0.665, Val Loss: 0.96, Val Acc: 0.665, Test Loss: 1.02, Test Acc: 0.647
# Epoch: 0, Bps: 45.74, Global step:   1562,
#  Train Loss: 0.82, Train Acc: 0.715, Val Loss: 0.84, Val Acc: 0.711, Test Loss: 0.88, Test Acc: 0.694
# Epoch: 1, Bps: 46.30, Global step:   2343,
#  Train Loss: 0.67, Train Acc: 0.775, Val Loss: 0.64, Val Acc: 0.785, Test Loss: 0.76, Test Acc: 0.737
# Epoch: 1, Bps: 46.09, Global step:   3124,
#  Train Loss: 0.63, Train Acc: 0.792, Val Loss: 0.61, Val Acc: 0.790, Test Loss: 0.73, Test Acc: 0.755
# Epoch: 2, Bps: 46.38, Global step:   3905,
#  Train Loss: 0.66, Train Acc: 0.772, Val Loss: 0.62, Val Acc: 0.789, Test Loss: 0.80, Test Acc: 0.725
# Epoch: 2, Bps: 46.30, Global step:   4686,
#  Train Loss: 0.59, Train Acc: 0.804, Val Loss: 0.58, Val Acc: 0.811, Test Loss: 0.72, Test Acc: 0.760
# Epoch: 3, Bps: 46.43, Global step:   5467,
#  Train Loss: 0.52, Train Acc: 0.829, Val Loss: 0.46, Val Acc: 0.846, Test Loss: 0.69, Test Acc: 0.764
# Epoch: 3, Bps: 46.30, Global step:   6248,
#  Train Loss: 0.53, Train Acc: 0.824, Val Loss: 0.50, Val Acc: 0.830, Test Loss: 0.68, Test Acc: 0.768
# Epoch: 4, Bps: 46.43, Global step:   7029,
#  Train Loss: 0.60, Train Acc: 0.796, Val Loss: 0.56, Val Acc: 0.806, Test Loss: 0.79, Test Acc: 0.737
# Epoch: 4, Bps: 46.38, Global step:   7810,
#  Train Loss: 0.59, Train Acc: 0.797, Val Loss: 0.57, Val Acc: 0.810, Test Loss: 0.77, Test Acc: 0.736
# Early stop criteria met
# Early stopping.

# %%
import time
#With batch norm in classifier
#With augment_triain in augmented train
# AAA
epochs = 10
batch_size = 64
learning_rate = 5e-2 # Should be 5e-5 for LeNet
early_stop_count = 4

new_mean_std = False 
resize = 0
transform = 'flip'
dataloaders = load_cifar10(resize, new_mean_std, transform , batch_size)


l2_reg_lambda = 0.0 #1e-5
momentum = 0.0 
optimizer = 'SGD'
model = ExampleModel(image_channels=3, num_classes=10)
trainer = Trainer(batch_size, learning_rate, early_stop_count, epochs, model, dataloaders, l2_reg_lambda, momentum, optimizer)

trainer.train()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# ExampleModel(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (9): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (12): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (13): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): ReLU()
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=1152, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# Epoch: 0, Bps: 47.86, Global step:    781,
#  Train Loss: 1.01, Train Acc: 0.644, Val Loss: 0.97, Val Acc: 0.654, Test Loss: 1.05, Test Acc: 0.632
# Epoch: 0, Bps: 46.84, Global step:   1562,
#  Train Loss: 0.71, Train Acc: 0.752, Val Loss: 0.69, Val Acc: 0.761, Test Loss: 0.79, Test Acc: 0.727
# Epoch: 1, Bps: 46.99, Global step:   2343,
#  Train Loss: 0.64, Train Acc: 0.780, Val Loss: 0.62, Val Acc: 0.788, Test Loss: 0.78, Test Acc: 0.733
# Epoch: 1, Bps: 46.51, Global step:   3124,
#  Train Loss: 0.55, Train Acc: 0.810, Val Loss: 0.52, Val Acc: 0.815, Test Loss: 0.71, Test Acc: 0.759
# Epoch: 2, Bps: 46.66, Global step:   3905,
#  Train Loss: 0.50, Train Acc: 0.829, Val Loss: 0.45, Val Acc: 0.843, Test Loss: 0.73, Test Acc: 0.759
# Epoch: 2, Bps: 46.49, Global step:   4686,
#  Train Loss: 0.43, Train Acc: 0.852, Val Loss: 0.39, Val Acc: 0.861, Test Loss: 0.66, Test Acc: 0.776
# Epoch: 3, Bps: 46.59, Global step:   5467,
#  Train Loss: 0.38, Train Acc: 0.870, Val Loss: 0.31, Val Acc: 0.896, Test Loss: 0.70, Test Acc: 0.771
# Epoch: 3, Bps: 46.42, Global step:   6248,
#  Train Loss: 0.34, Train Acc: 0.885, Val Loss: 0.31, Val Acc: 0.896, Test Loss: 0.65, Test Acc: 0.790
# Epoch: 4, Bps: 46.53, Global step:   7029,
#  Train Loss: 0.41, Train Acc: 0.861, Val Loss: 0.33, Val Acc: 0.881, Test Loss: 0.87, Test Acc: 0.750
# Epoch: 4, Bps: 46.47, Global step:   7810,
#  Train Loss: 0.30, Train Acc: 0.898, Val Loss: 0.25, Val Acc: 0.916, Test Loss: 0.68, Test Acc: 0.782
# Epoch: 5, Bps: 46.50, Global step:   8591,
#  Train Loss: 0.29, Train Acc: 0.904, Val Loss: 0.21, Val Acc: 0.925, Test Loss: 0.82, Test Acc: 0.776
# Epoch: 5, Bps: 46.45, Global step:   9372,
#  Train Loss: 0.34, Train Acc: 0.876, Val Loss: 0.29, Val Acc: 0.896, Test Loss: 0.78, Test Acc: 0.760
# Epoch: 6, Bps: 46.50, Global step:  10153,
#  Train Loss: 0.20, Train Acc: 0.932, Val Loss: 0.14, Val Acc: 0.956, Test Loss: 0.78, Test Acc: 0.789
# Epoch: 6, Bps: 46.41, Global step:  10934,
#  Train Loss: 0.26, Train Acc: 0.909, Val Loss: 0.23, Val Acc: 0.922, Test Loss: 0.76, Test Acc: 0.778
# Epoch: 7, Bps: 46.48, Global step:  11715,
#  Train Loss: 0.19, Train Acc: 0.936, Val Loss: 0.12, Val Acc: 0.959, Test Loss: 0.85, Test Acc: 0.783
# Epoch: 7, Bps: 46.39, Global step:  12496,
#  Train Loss: 0.22, Train Acc: 0.925, Val Loss: 0.17, Val Acc: 0.940, Test Loss: 0.75, Test Acc: 0.784
# Epoch: 8, Bps: 46.31, Global step:  13277,
#  Train Loss: 0.13, Train Acc: 0.957, Val Loss: 0.07, Val Acc: 0.979, Test Loss: 0.81, Test Acc: 0.791
# Epoch: 8, Bps: 46.19, Global step:  14058,
#  Train Loss: 0.20, Train Acc: 0.930, Val Loss: 0.17, Val Acc: 0.944, Test Loss: 0.78, Test Acc: 0.781
# Epoch: 9, Bps: 46.25, Global step:  14839,
#  Train Loss: 0.11, Train Acc: 0.965, Val Loss: 0.05, Val Acc: 0.984, Test Loss: 0.85, Test Acc: 0.790
# Epoch: 9, Bps: 46.21, Global step:  15620,
#  Train Loss: 0.18, Train Acc: 0.937, Val Loss: 0.16, Val Acc: 0.944, Test Loss: 0.85, Test Acc: 0.777

# %%
import time
#With batch norm in classifier
#With augment_triain in augmented train
# bbb
epochs = 10
batch_size = 64
learning_rate = 5e-3# Should be 5e-5 for LeNet
early_stop_count = 4

new_mean_std = False 
resize = 0
transform = 'flip'
dataloaders = load_cifar10(resize, new_mean_std, transform , batch_size)


l2_reg_lambda = 0.0 #1e-5
momentum = 0.0 
optimizer = 'SGD'
model = ExampleModel(image_channels=3, num_classes=10)
trainer = Trainer(batch_size, learning_rate, early_stop_count, epochs, model, dataloaders, l2_reg_lambda, momentum, optimizer)

trainer.train()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# ExampleModel(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (9): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (12): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (13): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): ReLU()
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=1152, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# Epoch: 0, Bps: 47.64, Global step:    781,
#  Train Loss: 1.26, Train Acc: 0.591, Val Loss: 1.25, Val Acc: 0.602, Test Loss: 1.27, Test Acc: 0.585
# Epoch: 0, Bps: 46.45, Global step:   1562,
#  Train Loss: 1.01, Train Acc: 0.662, Val Loss: 1.02, Val Acc: 0.660, Test Loss: 1.05, Test Acc: 0.644
# Epoch: 1, Bps: 46.72, Global step:   2343,
#  Train Loss: 0.89, Train Acc: 0.701, Val Loss: 0.88, Val Acc: 0.710, Test Loss: 0.96, Test Acc: 0.668
# Epoch: 1, Bps: 46.32, Global step:   3124,
#  Train Loss: 0.79, Train Acc: 0.735, Val Loss: 0.79, Val Acc: 0.741, Test Loss: 0.88, Test Acc: 0.699
# Epoch: 2, Bps: 46.54, Global step:   3905,
#  Train Loss: 0.74, Train Acc: 0.749, Val Loss: 0.73, Val Acc: 0.755, Test Loss: 0.87, Test Acc: 0.699
# Epoch: 2, Bps: 46.42, Global step:   4686,
#  Train Loss: 0.67, Train Acc: 0.774, Val Loss: 0.67, Val Acc: 0.783, Test Loss: 0.81, Test Acc: 0.724
# Epoch: 3, Bps: 46.45, Global step:   5467,
#  Train Loss: 0.61, Train Acc: 0.798, Val Loss: 0.58, Val Acc: 0.815, Test Loss: 0.80, Test Acc: 0.728
# Epoch: 3, Bps: 46.21, Global step:   6248,
#  Train Loss: 0.57, Train Acc: 0.811, Val Loss: 0.55, Val Acc: 0.822, Test Loss: 0.77, Test Acc: 0.736
# Epoch: 4, Bps: 46.24, Global step:   7029,
#  Train Loss: 0.53, Train Acc: 0.825, Val Loss: 0.49, Val Acc: 0.836, Test Loss: 0.78, Test Acc: 0.735
# Epoch: 4, Bps: 46.06, Global step:   7810,
#  Train Loss: 0.60, Train Acc: 0.793, Val Loss: 0.58, Val Acc: 0.803, Test Loss: 0.85, Test Acc: 0.713
# Epoch: 5, Bps: 46.18, Global step:   8591,
#  Train Loss: 0.44, Train Acc: 0.854, Val Loss: 0.40, Val Acc: 0.867, Test Loss: 0.76, Test Acc: 0.741
# Epoch: 5, Bps: 46.16, Global step:   9372,
#  Train Loss: 0.46, Train Acc: 0.848, Val Loss: 0.43, Val Acc: 0.861, Test Loss: 0.76, Test Acc: 0.744
# Epoch: 6, Bps: 46.22, Global step:  10153,
#  Train Loss: 0.41, Train Acc: 0.863, Val Loss: 0.36, Val Acc: 0.879, Test Loss: 0.79, Test Acc: 0.731
# Epoch: 6, Bps: 46.18, Global step:  10934,
#  Train Loss: 0.39, Train Acc: 0.873, Val Loss: 0.36, Val Acc: 0.885, Test Loss: 0.75, Test Acc: 0.752
# Epoch: 7, Bps: 46.24, Global step:  11715,
#  Train Loss: 0.35, Train Acc: 0.888, Val Loss: 0.28, Val Acc: 0.911, Test Loss: 0.79, Test Acc: 0.741
# Epoch: 7, Bps: 46.14, Global step:  12496,
#  Train Loss: 0.37, Train Acc: 0.873, Val Loss: 0.34, Val Acc: 0.885, Test Loss: 0.79, Test Acc: 0.741
# Epoch: 8, Bps: 46.13, Global step:  13277,
#  Train Loss: 0.29, Train Acc: 0.910, Val Loss: 0.22, Val Acc: 0.934, Test Loss: 0.81, Test Acc: 0.741
# Epoch: 8, Bps: 46.17, Global step:  14058,
#  Train Loss: 0.31, Train Acc: 0.896, Val Loss: 0.28, Val Acc: 0.906, Test Loss: 0.78, Test Acc: 0.751
# Epoch: 9, Bps: 46.20, Global step:  14839,
#  Train Loss: 0.22, Train Acc: 0.933, Val Loss: 0.16, Val Acc: 0.959, Test Loss: 0.79, Test Acc: 0.748
# Epoch: 9, Bps: 46.10, Global step:  15620,
#  Train Loss: 0.31, Train Acc: 0.895, Val Loss: 0.27, Val Acc: 0.907, Test Loss: 0.83, Test Acc: 0.744

# %%
import time
#With batch norm in classifier
#With data_triain in augmented train
#ccc
epochs = 10
batch_size = 64
learning_rate = 5e-4 # Should be 5e-5 for LeNet
early_stop_count = 4

new_mean_std = False 
resize = 0
transform = 'flip'
dataloaders = load_cifar10(resize, new_mean_std, transform , batch_size)


l2_reg_lambda = 0.005 #1e-5
momentum = 0.0 
optimizer = 'SGD'
model = ExampleModel(image_channels=3, num_classes=10)
trainer = Trainer(batch_size, learning_rate, early_stop_count, epochs, model, dataloaders, l2_reg_lambda, momentum, optimizer)

trainer.train()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# ExampleModel(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (9): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (12): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (13): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): ReLU()
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=1152, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# Epoch: 0, Bps: 47.84, Global step:    781,
#  Train Loss: 1.85, Train Acc: 0.392, Val Loss: 1.87, Val Acc: 0.390, Test Loss: 1.85, Test Acc: 0.396
# Epoch: 0, Bps: 46.66, Global step:   1562,
#  Train Loss: 1.70, Train Acc: 0.448, Val Loss: 1.72, Val Acc: 0.448, Test Loss: 1.70, Test Acc: 0.452
# Epoch: 1, Bps: 46.81, Global step:   2343,
#  Train Loss: 1.59, Train Acc: 0.486, Val Loss: 1.60, Val Acc: 0.485, Test Loss: 1.60, Test Acc: 0.485
# Epoch: 1, Bps: 46.49, Global step:   3124,
#  Train Loss: 1.51, Train Acc: 0.515, Val Loss: 1.53, Val Acc: 0.513, Test Loss: 1.52, Test Acc: 0.510
# Epoch: 2, Bps: 46.57, Global step:   3905,
#  Train Loss: 1.44, Train Acc: 0.537, Val Loss: 1.45, Val Acc: 0.535, Test Loss: 1.45, Test Acc: 0.528
# Epoch: 2, Bps: 46.18, Global step:   4686,
#  Train Loss: 1.38, Train Acc: 0.555, Val Loss: 1.39, Val Acc: 0.552, Test Loss: 1.40, Test Acc: 0.542
# Epoch: 3, Bps: 45.98, Global step:   5467,
#  Train Loss: 1.33, Train Acc: 0.573, Val Loss: 1.34, Val Acc: 0.573, Test Loss: 1.35, Test Acc: 0.556
# Epoch: 3, Bps: 45.88, Global step:   6248,
#  Train Loss: 1.29, Train Acc: 0.586, Val Loss: 1.29, Val Acc: 0.584, Test Loss: 1.31, Test Acc: 0.573
# Epoch: 4, Bps: 45.91, Global step:   7029,
#  Train Loss: 1.24, Train Acc: 0.601, Val Loss: 1.25, Val Acc: 0.602, Test Loss: 1.27, Test Acc: 0.583
# Epoch: 4, Bps: 45.84, Global step:   7810,
#  Train Loss: 1.20, Train Acc: 0.613, Val Loss: 1.21, Val Acc: 0.614, Test Loss: 1.23, Test Acc: 0.593
# Epoch: 5, Bps: 45.94, Global step:   8591,
#  Train Loss: 1.17, Train Acc: 0.625, Val Loss: 1.17, Val Acc: 0.631, Test Loss: 1.20, Test Acc: 0.603
# Epoch: 5, Bps: 45.83, Global step:   9372,
#  Train Loss: 1.13, Train Acc: 0.636, Val Loss: 1.13, Val Acc: 0.639, Test Loss: 1.17, Test Acc: 0.614
# Epoch: 6, Bps: 45.86, Global step:  10153,
#  Train Loss: 1.10, Train Acc: 0.646, Val Loss: 1.10, Val Acc: 0.650, Test Loss: 1.14, Test Acc: 0.620
# Epoch: 6, Bps: 45.81, Global step:  10934,
#  Train Loss: 1.07, Train Acc: 0.655, Val Loss: 1.07, Val Acc: 0.656, Test Loss: 1.12, Test Acc: 0.629
# Epoch: 7, Bps: 45.89, Global step:  11715,
#  Train Loss: 1.05, Train Acc: 0.665, Val Loss: 1.05, Val Acc: 0.667, Test Loss: 1.10, Test Acc: 0.639
# Epoch: 7, Bps: 45.89, Global step:  12496,
#  Train Loss: 1.02, Train Acc: 0.671, Val Loss: 1.01, Val Acc: 0.677, Test Loss: 1.07, Test Acc: 0.646
# Epoch: 8, Bps: 45.96, Global step:  13277,
#  Train Loss: 1.00, Train Acc: 0.680, Val Loss: 0.98, Val Acc: 0.685, Test Loss: 1.06, Test Acc: 0.652
# Epoch: 8, Bps: 45.92, Global step:  14058,
#  Train Loss: 0.97, Train Acc: 0.688, Val Loss: 0.97, Val Acc: 0.694, Test Loss: 1.04, Test Acc: 0.659
# Epoch: 9, Bps: 45.95, Global step:  14839,
#  Train Loss: 0.95, Train Acc: 0.695, Val Loss: 0.94, Val Acc: 0.698, Test Loss: 1.02, Test Acc: 0.662
# Epoch: 9, Bps: 45.89, Global step:  15620,
#  Train Loss: 0.93, Train Acc: 0.699, Val Loss: 0.92, Val Acc: 0.704, Test Loss: 1.00, Test Acc: 0.667

# %%
import time
#With batch norm in classifier
#With data_triain in augmented train
#ddd same as ccc but without l2
epochs = 10
batch_size = 64
learning_rate = 5e-4 # Should be 5e-5 for LeNet
early_stop_count = 4

new_mean_std = False 
resize = 0
transform = 'flip'
dataloaders = load_cifar10(resize, new_mean_std, transform , batch_size)


l2_reg_lambda = 0#0.005 #1e-5
momentum = 0.0 
optimizer = 'SGD'
model = ExampleModel(image_channels=3, num_classes=10)
trainer = Trainer(batch_size, learning_rate, early_stop_count, epochs, model, dataloaders, l2_reg_lambda, momentum, optimizer)

trainer.train()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# ExampleModel(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (9): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (12): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (13): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): ReLU()
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=1152, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# Epoch: 0, Bps: 48.03, Global step:    781,
#  Train Loss: 1.84, Train Acc: 0.390, Val Loss: 1.84, Val Acc: 0.402, Test Loss: 1.84, Test Acc: 0.395
# Epoch: 0, Bps: 46.38, Global step:   1562,
#  Train Loss: 1.70, Train Acc: 0.447, Val Loss: 1.70, Val Acc: 0.460, Test Loss: 1.70, Test Acc: 0.446
# Epoch: 1, Bps: 46.42, Global step:   2343,
#  Train Loss: 1.61, Train Acc: 0.481, Val Loss: 1.60, Val Acc: 0.488, Test Loss: 1.60, Test Acc: 0.477
# Epoch: 1, Bps: 46.24, Global step:   3124,
#  Train Loss: 1.53, Train Acc: 0.504, Val Loss: 1.52, Val Acc: 0.514, Test Loss: 1.52, Test Acc: 0.502
# Epoch: 2, Bps: 46.28, Global step:   3905,
#  Train Loss: 1.45, Train Acc: 0.527, Val Loss: 1.45, Val Acc: 0.539, Test Loss: 1.46, Test Acc: 0.524
# Epoch: 2, Bps: 46.09, Global step:   4686,
#  Train Loss: 1.39, Train Acc: 0.546, Val Loss: 1.38, Val Acc: 0.558, Test Loss: 1.40, Test Acc: 0.542
# Epoch: 3, Bps: 45.89, Global step:   5467,
#  Train Loss: 1.34, Train Acc: 0.563, Val Loss: 1.33, Val Acc: 0.578, Test Loss: 1.35, Test Acc: 0.558
# Epoch: 3, Bps: 45.31, Global step:   6248,
#  Train Loss: 1.29, Train Acc: 0.578, Val Loss: 1.28, Val Acc: 0.593, Test Loss: 1.30, Test Acc: 0.569
# Epoch: 4, Bps: 45.33, Global step:   7029,
#  Train Loss: 1.25, Train Acc: 0.596, Val Loss: 1.23, Val Acc: 0.611, Test Loss: 1.26, Test Acc: 0.585
# Epoch: 4, Bps: 45.21, Global step:   7810,
#  Train Loss: 1.20, Train Acc: 0.608, Val Loss: 1.19, Val Acc: 0.620, Test Loss: 1.23, Test Acc: 0.596
# Epoch: 5, Bps: 45.12, Global step:   8591,
#  Train Loss: 1.17, Train Acc: 0.621, Val Loss: 1.15, Val Acc: 0.637, Test Loss: 1.19, Test Acc: 0.605
# Epoch: 5, Bps: 45.12, Global step:   9372,
#  Train Loss: 1.13, Train Acc: 0.632, Val Loss: 1.12, Val Acc: 0.645, Test Loss: 1.16, Test Acc: 0.616
# Epoch: 6, Bps: 45.22, Global step:  10153,
#  Train Loss: 1.10, Train Acc: 0.642, Val Loss: 1.08, Val Acc: 0.655, Test Loss: 1.13, Test Acc: 0.625
# Epoch: 6, Bps: 45.23, Global step:  10934,
#  Train Loss: 1.07, Train Acc: 0.651, Val Loss: 1.05, Val Acc: 0.663, Test Loss: 1.11, Test Acc: 0.631
# Epoch: 7, Bps: 45.29, Global step:  11715,
#  Train Loss: 1.04, Train Acc: 0.661, Val Loss: 1.02, Val Acc: 0.676, Test Loss: 1.08, Test Acc: 0.642
# Epoch: 7, Bps: 45.25, Global step:  12496,
#  Train Loss: 1.01, Train Acc: 0.668, Val Loss: 0.99, Val Acc: 0.682, Test Loss: 1.06, Test Acc: 0.646
# Epoch: 8, Bps: 45.35, Global step:  13277,
#  Train Loss: 0.98, Train Acc: 0.678, Val Loss: 0.96, Val Acc: 0.692, Test Loss: 1.04, Test Acc: 0.653
# Epoch: 8, Bps: 45.30, Global step:  14058,
#  Train Loss: 0.96, Train Acc: 0.688, Val Loss: 0.94, Val Acc: 0.702, Test Loss: 1.02, Test Acc: 0.657
# Epoch: 9, Bps: 45.37, Global step:  14839,
#  Train Loss: 0.94, Train Acc: 0.695, Val Loss: 0.92, Val Acc: 0.709, Test Loss: 1.00, Test Acc: 0.661
# Epoch: 9, Bps: 45.33, Global step:  15620,
#  Train Loss: 0.92, Train Acc: 0.701, Val Loss: 0.90, Val Acc: 0.714, Test Loss: 0.99, Test Acc: 0.665

# %%
import time
#With batch norm in classifier
#With data_triain in augmented train
#eee same as bbb but larger alpha
epochs = 10
batch_size = 64
learning_rate =  0.005# Should be 5e-5 for LeNet
early_stop_count = 4

new_mean_std = False 
resize = 0
transform = 'flip'
dataloaders = load_cifar10(resize, new_mean_std, transform , batch_size)


l2_reg_lambda = 0.005 #1e-5
momentum = 0.0 
optimizer = 'SGD'
model = ExampleModel(image_channels=3, num_classes=10)
trainer = Trainer(batch_size, learning_rate, early_stop_count, epochs, model, dataloaders, l2_reg_lambda, momentum, optimizer)

trainer.train()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# ExampleModel(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (9): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (12): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (13): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): ReLU()
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=1152, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# Epoch: 0, Bps: 47.03, Global step:    781,
#  Train Loss: 1.27, Train Acc: 0.582, Val Loss: 1.27, Val Acc: 0.578, Test Loss: 1.28, Test Acc: 0.573
# Epoch: 0, Bps: 46.14, Global step:   1562,
#  Train Loss: 1.04, Train Acc: 0.659, Val Loss: 1.04, Val Acc: 0.657, Test Loss: 1.07, Test Acc: 0.646
# Epoch: 1, Bps: 45.91, Global step:   2343,
#  Train Loss: 0.90, Train Acc: 0.703, Val Loss: 0.89, Val Acc: 0.706, Test Loss: 0.96, Test Acc: 0.670
# Epoch: 1, Bps: 45.42, Global step:   3124,
#  Train Loss: 0.82, Train Acc: 0.730, Val Loss: 0.82, Val Acc: 0.730, Test Loss: 0.91, Test Acc: 0.696
# Epoch: 2, Bps: 45.71, Global step:   3905,
#  Train Loss: 0.72, Train Acc: 0.763, Val Loss: 0.70, Val Acc: 0.770, Test Loss: 0.84, Test Acc: 0.719
# Epoch: 2, Bps: 45.68, Global step:   4686,
#  Train Loss: 0.66, Train Acc: 0.785, Val Loss: 0.64, Val Acc: 0.791, Test Loss: 0.79, Test Acc: 0.734
# Epoch: 3, Bps: 45.94, Global step:   5467,
#  Train Loss: 0.60, Train Acc: 0.807, Val Loss: 0.56, Val Acc: 0.817, Test Loss: 0.78, Test Acc: 0.737
# Epoch: 3, Bps: 45.82, Global step:   6248,
#  Train Loss: 0.61, Train Acc: 0.799, Val Loss: 0.59, Val Acc: 0.802, Test Loss: 0.78, Test Acc: 0.734
# Epoch: 4, Bps: 45.92, Global step:   7029,
#  Train Loss: 0.52, Train Acc: 0.837, Val Loss: 0.48, Val Acc: 0.854, Test Loss: 0.75, Test Acc: 0.747
# Epoch: 4, Bps: 45.86, Global step:   7810,
#  Train Loss: 0.51, Train Acc: 0.833, Val Loss: 0.49, Val Acc: 0.840, Test Loss: 0.73, Test Acc: 0.750
# Epoch: 5, Bps: 45.95, Global step:   8591,
#  Train Loss: 0.46, Train Acc: 0.857, Val Loss: 0.41, Val Acc: 0.883, Test Loss: 0.74, Test Acc: 0.750
# Epoch: 5, Bps: 45.95, Global step:   9372,
#  Train Loss: 0.49, Train Acc: 0.840, Val Loss: 0.46, Val Acc: 0.841, Test Loss: 0.76, Test Acc: 0.743
# Epoch: 6, Bps: 46.02, Global step:  10153,
#  Train Loss: 0.42, Train Acc: 0.865, Val Loss: 0.37, Val Acc: 0.889, Test Loss: 0.76, Test Acc: 0.740
# Epoch: 6, Bps: 45.89, Global step:  10934,
#  Train Loss: 0.45, Train Acc: 0.851, Val Loss: 0.42, Val Acc: 0.861, Test Loss: 0.76, Test Acc: 0.738
# Epoch: 7, Bps: 45.89, Global step:  11715,
#  Train Loss: 0.37, Train Acc: 0.882, Val Loss: 0.31, Val Acc: 0.908, Test Loss: 0.77, Test Acc: 0.741
# Epoch: 7, Bps: 45.75, Global step:  12496,
#  Train Loss: 0.41, Train Acc: 0.866, Val Loss: 0.37, Val Acc: 0.885, Test Loss: 0.76, Test Acc: 0.742
# Epoch: 8, Bps: 45.82, Global step:  13277,
#  Train Loss: 0.33, Train Acc: 0.896, Val Loss: 0.26, Val Acc: 0.921, Test Loss: 0.77, Test Acc: 0.746
# Epoch: 8, Bps: 45.82, Global step:  14058,
#  Train Loss: 0.38, Train Acc: 0.877, Val Loss: 0.34, Val Acc: 0.892, Test Loss: 0.77, Test Acc: 0.745
# Epoch: 9, Bps: 45.89, Global step:  14839,
#  Train Loss: 0.29, Train Acc: 0.911, Val Loss: 0.22, Val Acc: 0.942, Test Loss: 0.76, Test Acc: 0.753
# Epoch: 9, Bps: 45.82, Global step:  15620,
#  Train Loss: 0.33, Train Acc: 0.893, Val Loss: 0.29, Val Acc: 0.906, Test Loss: 0.74, Test Acc: 0.759

# %%
import time
#With batch norm in classifier
#With data_triain in augmented train
#fff 0.005 -> 0.003
epochs = 10
batch_size = 64
learning_rate =  0.003# Should be 5e-5 for LeNet
early_stop_count = 4

new_mean_std = False 
resize = 0
transform = 'flip'
dataloaders = load_cifar10(resize, new_mean_std, transform , batch_size)


l2_reg_lambda = 0.005 #1e-5
momentum = 0.0 
optimizer = 'SGD'
model = ExampleModel(image_channels=3, num_classes=10)
trainer = Trainer(batch_size, learning_rate, early_stop_count, epochs, model, dataloaders, l2_reg_lambda, momentum, optimizer)

trainer.train()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# ExampleModel(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (9): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (12): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (13): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): ReLU()
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=1152, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# Epoch: 0, Bps: 46.28, Global step:    781,
#  Train Loss: 1.40, Train Acc: 0.549, Val Loss: 1.41, Val Acc: 0.551, Test Loss: 1.41, Test Acc: 0.548
# Epoch: 0, Bps: 46.05, Global step:   1562,
#  Train Loss: 1.17, Train Acc: 0.616, Val Loss: 1.17, Val Acc: 0.610, Test Loss: 1.19, Test Acc: 0.606
# Epoch: 1, Bps: 45.92, Global step:   2343,
#  Train Loss: 1.03, Train Acc: 0.653, Val Loss: 1.03, Val Acc: 0.661, Test Loss: 1.08, Test Acc: 0.636
# Epoch: 1, Bps: 45.65, Global step:   3124,
#  Train Loss: 0.93, Train Acc: 0.690, Val Loss: 0.93, Val Acc: 0.693, Test Loss: 1.00, Test Acc: 0.661
# Epoch: 2, Bps: 45.83, Global step:   3905,
#  Train Loss: 0.85, Train Acc: 0.722, Val Loss: 0.83, Val Acc: 0.736, Test Loss: 0.93, Test Acc: 0.686
# Epoch: 2, Bps: 45.61, Global step:   4686,
#  Train Loss: 0.77, Train Acc: 0.751, Val Loss: 0.75, Val Acc: 0.763, Test Loss: 0.87, Test Acc: 0.708
# Epoch: 3, Bps: 45.63, Global step:   5467,
#  Train Loss: 0.71, Train Acc: 0.771, Val Loss: 0.69, Val Acc: 0.786, Test Loss: 0.84, Test Acc: 0.715
# Epoch: 3, Bps: 45.47, Global step:   6248,
#  Train Loss: 0.69, Train Acc: 0.773, Val Loss: 0.67, Val Acc: 0.782, Test Loss: 0.82, Test Acc: 0.721
# Epoch: 4, Bps: 45.57, Global step:   7029,
#  Train Loss: 0.63, Train Acc: 0.797, Val Loss: 0.60, Val Acc: 0.809, Test Loss: 0.79, Test Acc: 0.731
# Epoch: 4, Bps: 45.50, Global step:   7810,
#  Train Loss: 0.61, Train Acc: 0.799, Val Loss: 0.59, Val Acc: 0.801, Test Loss: 0.79, Test Acc: 0.730
# Epoch: 5, Bps: 45.50, Global step:   8591,
#  Train Loss: 0.58, Train Acc: 0.813, Val Loss: 0.54, Val Acc: 0.825, Test Loss: 0.80, Test Acc: 0.729
# Epoch: 5, Bps: 45.49, Global step:   9372,
#  Train Loss: 0.55, Train Acc: 0.827, Val Loss: 0.53, Val Acc: 0.839, Test Loss: 0.77, Test Acc: 0.738
# Epoch: 6, Bps: 45.57, Global step:  10153,
#  Train Loss: 0.51, Train Acc: 0.839, Val Loss: 0.46, Val Acc: 0.865, Test Loss: 0.78, Test Acc: 0.736
# Epoch: 6, Bps: 45.51, Global step:  10934,
#  Train Loss: 0.58, Train Acc: 0.809, Val Loss: 0.55, Val Acc: 0.823, Test Loss: 0.84, Test Acc: 0.713
# Epoch: 7, Bps: 45.58, Global step:  11715,
#  Train Loss: 0.46, Train Acc: 0.859, Val Loss: 0.41, Val Acc: 0.880, Test Loss: 0.77, Test Acc: 0.739
# Epoch: 7, Bps: 45.55, Global step:  12496,
#  Train Loss: 0.49, Train Acc: 0.843, Val Loss: 0.46, Val Acc: 0.854, Test Loss: 0.78, Test Acc: 0.732
# Epoch: 8, Bps: 45.65, Global step:  13277,
#  Train Loss: 0.41, Train Acc: 0.876, Val Loss: 0.36, Val Acc: 0.900, Test Loss: 0.77, Test Acc: 0.746
# Epoch: 8, Bps: 45.61, Global step:  14058,
#  Train Loss: 0.43, Train Acc: 0.862, Val Loss: 0.39, Val Acc: 0.877, Test Loss: 0.77, Test Acc: 0.739
# Epoch: 9, Bps: 45.69, Global step:  14839,
#  Train Loss: 0.36, Train Acc: 0.893, Val Loss: 0.30, Val Acc: 0.916, Test Loss: 0.76, Test Acc: 0.748
# Epoch: 9, Bps: 45.58, Global step:  15620,
#  Train Loss: 0.39, Train Acc: 0.874, Val Loss: 0.36, Val Acc: 0.890, Test Loss: 0.77, Test Acc: 0.740

# %%
import time
#With batch norm in classifier
#With data_triain in augmented train
#eee same as bbb but larger alpha AGAIN
epochs = 10
batch_size = 64
learning_rate =  0.005# Should be 5e-5 for LeNet
early_stop_count = 4

new_mean_std = False 
resize = 0
transform = 'flip'
dataloaders = load_cifar10(resize, new_mean_std, transform , batch_size)


l2_reg_lambda = 0.005 #1e-5
momentum = 0.0 
optimizer = 'SGD'
model = ExampleModel(image_channels=3, num_classes=10)
trainer = Trainer(batch_size, learning_rate, early_stop_count, epochs, model, dataloaders, l2_reg_lambda, momentum, optimizer)

trainer.train()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# ExampleModel(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (9): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (12): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (13): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): ReLU()
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=1152, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# Epoch: 0, Bps: 47.58, Global step:    781,
#  Train Loss: 1.26, Train Acc: 0.584, Val Loss: 1.25, Val Acc: 0.587, Test Loss: 1.28, Test Acc: 0.575
# Epoch: 0, Bps: 45.45, Global step:   1562,
#  Train Loss: 1.05, Train Acc: 0.650, Val Loss: 1.05, Val Acc: 0.651, Test Loss: 1.09, Test Acc: 0.630
# Epoch: 1, Bps: 46.00, Global step:   2343,
#  Train Loss: 0.90, Train Acc: 0.702, Val Loss: 0.88, Val Acc: 0.711, Test Loss: 0.97, Test Acc: 0.672
# Epoch: 1, Bps: 45.86, Global step:   3124,
#  Train Loss: 0.83, Train Acc: 0.723, Val Loss: 0.82, Val Acc: 0.724, Test Loss: 0.92, Test Acc: 0.690
# Epoch: 2, Bps: 45.83, Global step:   3905,
#  Train Loss: 0.71, Train Acc: 0.768, Val Loss: 0.69, Val Acc: 0.775, Test Loss: 0.84, Test Acc: 0.715
# Epoch: 2, Bps: 45.76, Global step:   4686,
#  Train Loss: 0.69, Train Acc: 0.769, Val Loss: 0.67, Val Acc: 0.779, Test Loss: 0.83, Test Acc: 0.715
# Epoch: 3, Bps: 45.72, Global step:   5467,
#  Train Loss: 0.61, Train Acc: 0.800, Val Loss: 0.58, Val Acc: 0.807, Test Loss: 0.79, Test Acc: 0.730
# Epoch: 3, Bps: 45.75, Global step:   6248,
#  Train Loss: 0.58, Train Acc: 0.811, Val Loss: 0.55, Val Acc: 0.823, Test Loss: 0.76, Test Acc: 0.747
# Epoch: 4, Bps: 45.89, Global step:   7029,
#  Train Loss: 0.54, Train Acc: 0.827, Val Loss: 0.49, Val Acc: 0.840, Test Loss: 0.77, Test Acc: 0.739
# Epoch: 4, Bps: 45.80, Global step:   7810,
#  Train Loss: 0.56, Train Acc: 0.812, Val Loss: 0.52, Val Acc: 0.827, Test Loss: 0.78, Test Acc: 0.736
# Epoch: 5, Bps: 45.83, Global step:   8591,
#  Train Loss: 0.47, Train Acc: 0.850, Val Loss: 0.42, Val Acc: 0.871, Test Loss: 0.76, Test Acc: 0.746
# Epoch: 5, Bps: 45.75, Global step:   9372,
#  Train Loss: 0.50, Train Acc: 0.833, Val Loss: 0.46, Val Acc: 0.852, Test Loss: 0.80, Test Acc: 0.732
# Epoch: 6, Bps: 45.73, Global step:  10153,
#  Train Loss: 0.42, Train Acc: 0.865, Val Loss: 0.36, Val Acc: 0.887, Test Loss: 0.76, Test Acc: 0.747
# Epoch: 6, Bps: 45.65, Global step:  10934,
#  Train Loss: 0.45, Train Acc: 0.851, Val Loss: 0.41, Val Acc: 0.864, Test Loss: 0.76, Test Acc: 0.749
# Epoch: 7, Bps: 45.70, Global step:  11715,
#  Train Loss: 0.37, Train Acc: 0.884, Val Loss: 0.31, Val Acc: 0.907, Test Loss: 0.78, Test Acc: 0.742
# Epoch: 7, Bps: 45.67, Global step:  12496,
#  Train Loss: 0.42, Train Acc: 0.863, Val Loss: 0.38, Val Acc: 0.882, Test Loss: 0.78, Test Acc: 0.741
# Epoch: 8, Bps: 45.76, Global step:  13277,
#  Train Loss: 0.33, Train Acc: 0.899, Val Loss: 0.26, Val Acc: 0.923, Test Loss: 0.78, Test Acc: 0.745
# Epoch: 8, Bps: 45.66, Global step:  14058,
#  Train Loss: 0.38, Train Acc: 0.877, Val Loss: 0.33, Val Acc: 0.894, Test Loss: 0.77, Test Acc: 0.751
# Epoch: 9, Bps: 45.74, Global step:  14839,
#  Train Loss: 0.26, Train Acc: 0.922, Val Loss: 0.20, Val Acc: 0.949, Test Loss: 0.74, Test Acc: 0.758
# Epoch: 9, Bps: 45.72, Global step:  15620,
#  Train Loss: 0.34, Train Acc: 0.889, Val Loss: 0.30, Val Acc: 0.910, Test Loss: 0.75, Test Acc: 0.754

# %%
create_plots(trainer, "task3")

# %%
create_plots(trainer, "task3") #With batch norm in classifier
#With augment_triain in augmented train
#With L2 regularisation 
#Without Momentum

# %%
# AAA
create_plots(trainer, "task3")

# %%
# bbb
create_plots(trainer, "task3")

# %%
# ccc
create_plots(trainer, "task3")

# %%
#ddd same as ccc but without l2 0.0005
create_plots(trainer, "task3")

# %%
#eeee 0.005
create_plots(trainer, "task3")

# %%
#ffff 0.003
create_plots(trainer, "task3")

# %%
#eeee again
create_plots(trainer, "task3")
